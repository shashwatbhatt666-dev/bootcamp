# %%
pip install ultralytics opencv-python
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.161-py3-none-any.whl.metadata (46 kB)
# Requirement already satisfied: opencv-python in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (5.0.0.93)
# Collecting cloudpickle>=3.1.1 (from ultralytics)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting filelock>=3.16.1 (from ultralytics)
#   Downloading filelock-4.0.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy>=1.23.0 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics) (2.5.1)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics) (3.11.2)
# Requirement already satisfied: pillow>=7.1.2 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics) (12.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics) (2.34.2)
# Collecting torch>=1.8.0 (from ultralytics)
#   Downloading torch-2.14.0-cp314-cp314-win_amd64.whl.metadata (38 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.29.0-cp314-cp314-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: psutil>=5.8.0 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics) (7.2.2)
# Collecting polars>=0.20.0 (from ultralytics)
#   Downloading polars-1.44.2-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-ml-py>=12.0.0 (from ultralytics)
#   Downloading nvidia_ml_py-13.610.43-py3-none-any.whl.metadata (9.7 kB)
# Collecting ultralytics-thop>=2.1.6 (from ultralytics)
#   Downloading ultralytics_thop-2.1.6-py3-none-any.whl.metadata (13 kB)
# Collecting ultralytics-platform>=0.1.45 (from ultralytics)
#   Downloading ultralytics_platform-0.1.62-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (26.3)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting polars-runtime-32==1.44.2 (from polars>=0.20.0->ultralytics)
#   Downloading polars_runtime_32-1.44.2-cp310-abi3-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.23.0->ultralytics) (2.8.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.23.0->ultralytics) (2026.7.22)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch>=1.8.0->ultralytics) (4.16.0)
# Collecting setuptools>=77.0.3 (from torch>=1.8.0->ultralytics)
#   Downloading setuptools-84.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch>=1.8.0->ultralytics)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=1.8.0->ultralytics)
#   Downloading networkx-3.7-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: jinja2 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch>=1.8.0->ultralytics)
#   Downloading fsspec-2026.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.8.0->ultralytics)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: httpx<1,>=0.28 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics-platform>=0.1.45->ultralytics) (0.28.1)
# Requirement already satisfied: anyio in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (4.14.1)
# Requirement already satisfied: httpcore==1.* in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.161-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.5 MB ? eta -:--:--
#    -------------- ------------------------- 0.5/1.5 MB 758.9 kB/s eta 0:00:02
#    --------------------- ------------------ 0.8/1.5 MB 961.5 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.5 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 1.2 MB/s  0:00:01
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading filelock-4.0.3-py3-none-any.whl (108 kB)
# Downloading nvidia_ml_py-13.610.43-py3-none-any.whl (53 kB)
# Downloading polars-1.44.2-py3-none-any.whl (865 kB)
#    ---------------------------------------- 0.0/865.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/865.8 kB ? eta -:--:--
#    ------------------------ --------------- 524.3/865.8 kB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 786.4/865.8 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 865.8/865.8 kB 1.4 MB/s  0:00:00
# Downloading polars_runtime_32-1.44.2-cp310-abi3-win_amd64.whl (51.3 MB)
#    ---------------------------------------- 0.0/51.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/51.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/51.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/51.3 MB ? eta -:--:--
#    ---------------------------------------- 0.5/51.3 MB 1.2 MB/s eta 0:00:45
#     --------------------------------------- 0.8/51.3 MB 1.0 MB/s eta 0:00:50
#     --------------------------------------- 1.0/51.3 MB 1.1 MB/s eta 0:00:47
#    - -------------------------------------- 1.3/51.3 MB 1.2 MB/s eta 0:00:43
#    - -------------------------------------- 1.3/51.3 MB 1.2 MB/s eta 0:00:43
#    - -------------------------------------- 1.6/51.3 MB 1.1 MB/s eta 0:00:45
#    - -------------------------------------- 1.6/51.3 MB 1.1 MB/s eta 0:00:45
#    - -------------------------------------- 1.6/51.3 MB 1.1 MB/s eta 0:00:45
#    - -------------------------------------- 1.8/51.3 MB 848.9 kB/s eta 0:00:59
#    - -------------------------------------- 1.8/51.3 MB 848.9 kB/s eta 0:00:59
#    - -------------------------------------- 2.1/51.3 MB 776.5 kB/s eta 0:01:04
#    - -------------------------------------- 2.4/51.3 MB 807.8 kB/s eta 0:01:01
#    - -------------------------------------- 2.4/51.3 MB 807.8 kB/s eta 0:01:01
#    - -------------------------------------- 2.4/51.3 MB 807.8 kB/s eta 0:01:01
#    -- ------------------------------------- 2.6/51.3 MB 766.0 kB/s eta 0:01:04
9 MB/s eta 0:00:07
#    ---------------------------------- ----- 105.9/124.1 MB 2.9 MB/s eta 0:00:07
#    ---------------------------------- ----- 107.0/124.1 MB 2.9 MB/s eta 0:00:06
#    ---------------------------------- ----- 107.5/124.1 MB 2.9 MB/s eta 0:00:06
#    ---------------------------------- ----- 108.3/124.1 MB 2.9 MB/s eta 0:00:06
#    ----------------------------------- ---- 109.3/124.1 MB 3.0 MB/s eta 0:00:06
#    ----------------------------------- ---- 110.1/124.1 MB 3.0 MB/s eta 0:00:05
#    ----------------------------------- ---- 110.9/124.1 MB 3.0 MB/s eta 0:00:05
#    ----------------------------------- ---- 111.4/124.1 MB 3.0 MB/s eta 0:00:05
#    ------------------------------------ --- 112.2/124.1 MB 3.0 MB/s eta 0:00:05
#    ------------------------------------ --- 113.0/124.1 MB 3.0 MB/s eta 0:00:04
#    ------------------------------------ --- 113.8/124.1 MB 2.9 MB/s eta 0:00:04
#    ------------------------------------ --- 113.8/124.1 MB 2.9 MB/s eta 0:00:04
#    ------------------------------------- -- 114.8/124.1 MB 2.9 MB/s eta 0:00:04
#    ------------------------------------- -- 115.1/124.1 MB 2.9 MB/s eta 0:00:04
#    ------------------------------------- -- 116.1/124.1 MB 2.9 MB/s eta 0:00:03
#    ------------------------------------- -- 117.4/124.1 MB 3.0 MB/s eta 0:00:03
#    -------------------------------------- - 118.5/124.1 MB 3.1 MB/s eta 0:00:02
#    -------------------------------------- - 119.3/124.1 MB 3.1 MB/s eta 0:00:02
#    -------------------------------------- - 119.8/124.1 MB 3.1 MB/s eta 0:00:02
#    -------------------------------------- - 120.1/124.1 MB 3.1 MB/s eta 0:00:02
#    -------------------------------------- - 120.8/124.1 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------------  122.2/124.1 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  122.9/124.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 124.1/124.1 MB 3.1 MB/s  0:00:48
# Downloading fsspec-2026.9.0-py3-none-any.whl (221 kB)
# Downloading networkx-3.7-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----------------------------- ---------- 1.6/2.1 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 7.0 MB/s  0:00:00
# Downloading setuptools-84.0.0-py3-none-any.whl (818 kB)
#    ---------------------------------------- 0.0/818.2 kB ? eta -:--:--
#    ------------------------- -------------- 524.3/818.2 kB 2.5 MB/s eta 0:00:01
#    ------------------------- -------------- 524.3/818.2 kB 2.5 MB/s eta 0:00:01
#    ------------------------- -------------- 524.3/818.2 kB 2.5 MB/s eta 0:00:01
#    ------------------------- -------------- 524.3/818.2 kB 2.5 MB/s eta 0:00:01
#    ------------------------- -------------- 524.3/818.2 kB 2.5 MB/s eta 0:00:01
#    ------------------------- -------------- 524.3/818.2 kB 2.5 MB/s eta 0:00:01
#    ------------------------- -------------- 524.3/818.2 kB 2.5 MB/s eta 0:00:01
#    ------------------------------------ - 786.4/818.2 kB 347.4 kB/s eta 0:00:01
#    ------------------------------------ - 786.4/818.2 kB 347.4 kB/s eta 0:00:01
#    ---------------------------------------- 818.2/818.2 kB 305.0 kB/s  0:00:01
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.3 MB 348.5 kB/s eta 0:00:17
#    --- ------------------------------------ 0.5/6.3 MB 348.5 kB/s eta 0:00:17
#    ---- ----------------------------------- 0.8/6.3 MB 417.5 kB/s eta 0:00:14
#    ------ --------------------------------- 1.0/6.3 MB 529.1 kB/s eta 0:00:10
#    -------- ------------------------------- 1.3/6.3 MB 610.7 kB/s eta 0:00:09
#    ----------- ---------------------------- 1.8/6.3 MB 822.0 kB/s eta 0:00:06
#    -------------- ------------------------- 2.4/6.3 MB 999.1 kB/s eta 0:00:04
#    ------------------- -------------------- 3.1/6.3 MB 1.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 3.7/6.3 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 4.5/6.3 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 5.2/6.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 5.8/6.3 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.3 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 1.7 MB/s  0:00:05
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 1.8 MB/s  0:00:00
# Downloading torchvision-0.29.0-cp314-cp314-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------------------------------ --------- 1.0/1.4 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 5.0 MB/s  0:00:00
# Downloading ultralytics_platform-0.1.62-py3-none-any.whl (90 kB)
# Downloading ultralytics_thop-2.1.6-py3-none-any.whl (30 kB)
# Installing collected packages: nvidia-ml-py, mpmath, sympy, setuptools, polars-runtime-32, networkx, fsspec, filelock, cloudpickle, torch, polars, ultralytics-thop, ultralytics-platform, torchvision, ultralytics
#
#    -- -------------------------------------  1/15 [mpmath]
#    -- -------------------------------------  1/15 [mpmath]
#    -- -------------------------------------  1/15 [mpmath]
#    -- -------------------------------------  1/15 [mpmath]
#    -- -------------------------------------  1/15 [mpmath]
#    -- -------------------------------------  1/15 [mpmath]
#    -- -------------------------------------  1/15 [mpmath]
#    -- -------------------------------------  1/15 [mpmath]
#    -- -------------------------------------  1/15 [mpmath]
#    -- -------------------------------------  1/15 [mpmath]
#    -- -------------------------------------  1/15 [mpmath]
#    -- -------------------------------------  1/15 [mpmath]
#    -- -------------------------------------  1/15 [mpmath]
#    -- -------------------------------------  1/15 [mpmath]
#    -- -------------------------------------  1/15 [mpmath]
#    -- -------------------------------------  1/15 [mpmath]
#    -- -------------------------------------  1/15 [mpmath]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
# ...
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    -------------------------- ------------- 10/15 [polars]
#    ----------------------------- ---------- 11/15 [ultralytics-thop]
#    -------------------------------- ------- 12/15 [ultralytics-platform]
#    -------------------------------- ------- 12/15 [ultralytics-platform]
#    -------------------------------- ------- 12/15 [ultralytics-platform]
#    -------------------------------- ------- 12/15 [ultralytics-platform]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ------------------------------------- -- 14/15 [ultralytics]
#    ---------------------------------------- 15/15 [ultralytics]
#
# Successfully installed cloudpickle-3.1.2 filelock-4.0.3 fsspec-2026.9.0 mpmath-1.3.0 networkx-3.7 nvidia-ml-py-13.610.43 polars-1.44.2 polars-runtime-32-1.44.2 setuptools-84.0.0 sympy-1.14.0 torch-2.14.0 torchvision-0.29.0 ultralytics-8.4.161 ultralytics-platform-0.1.62 ultralytics-thop-2.1.6
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
from ultralytics import settings

# Disable data and crash report tracking
settings.update({"sync": False})
from ultralytics import YOLO

# 1. Load the lightweight YOLOv8 Nano model (~6MB, runs fast on CPU)
model = YOLO('yolov8n.pt')

# 2. Open the webcam (0 is default built-in camera)
cap = cv2.VideoCapture(0)

print("Starting Object Counter... Press 'q' on the video window to quit.")

while cap.isOpened():
  success, frame = cap.read()
  if not success:
    print("Failed to grab camera frame.")
    break

  # 3. Perform object detection on the current frame
  results = model(frame, verbose=False)

  # Get total number of objects detected in this frame
  detected_count = len(results[0].boxes)

  # 4. Render detection boxes directly on the frame
  annotated_frame = results[0].plot()

  # 5. Display the object count overlay on screen
  cv2.putText(
      annotated_frame,
      f'Total Objects Counted: {detected_count}',
      (20, 50),  # Position (x, y)
      cv2.FONT_HERSHEY_SIMPLEX,
      1,  # Font scale
      (0, 255, 0),  # Text color (Green)
      2,  # Thickness
      cv2.LINE_AA,
  )

  # 6. Show the frame in a window
  cv2.imshow('BCA AI Demo - Live Object Counter', annotated_frame)

  # 7. Terminate program cleanly when pressing 'q'
  if cv2.waitKey(1) & 0xFF == ord('q'):
    print("Terminating program...")
    break

# Release camera and close all windows cleanly
cap.release()

# 2. Add short wait key loops to let Windows pump destroy events cleanly
cv2.waitKey(1)
cv2.destroyAllWindows()
cv2.waitKey(1)

print("Camera feed closed successfully.")
# Out:
# Creating new Ultralytics Settings v0.0.8 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Shashwat Bhatt\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 1.7MB/s 3.8s.7s<0.1s4s19.5s
# Starting Object Counter... Press 'q' on the video window to quit.
# Failed to grab camera frame.
# Camera feed closed successfully.

# %% [markdown]
# **----------------------------------------------------------------------------**
# **Project Ideas- Real-Time Object Counting (e.g., Traffic / Store Counter)**
#
# Use a light pretrained model (like YOLOv8-nano) to count the number of cars, people, or smartphones shown in a video stream.
#
# **The Hook:** Shows how retail stores analyze foot traffic or how smart cities manage traffic lights.
#
# **Why it Works:** The ultralytics library allows running state-of-the-art YOLO object detection in just 3 lines of code.
#
# **Tech Stack:** ultralytics (YOLOv8), opencv-python

# %% [markdown]
# **--------- License Plate Reader (Automatic Number Plate Recognition - ANPR)----------**
#
# Pass a sample photo of a parked vehicle, crop the license plate using a pre-trained detector, and convert the plate image into readable text.
#
# **The Hook:** Demonstrates how automated toll booths (like FASTag systems) work in real life.
#
# **Core Concept:** Combines Image Preprocessing (Grayscale, Thresholding) with OCR (Optical Character Recognition).
#
# **Tech Stack:** opencv-python, easyocr or pytesseract

# %% [markdown]
# **------------Air-Canvas: Virtual Drawing Pad-------------**
#
# You can draw on your computer screen by simply waving an object
# like a red marker or finger in front of the camera.
#
# **The Hook:** Turning a webcam into an interactive touch screen.
#
# **Core Concept:** Teaches basic Color Masking (HSV Space) and Contour Detection in OpenCV.
#
# **Tech Stack:** opencv-python, numpy
