# %%
# !pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.0.1)
# Requirement already satisfied: absl-py~=2.3 in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mediapipe) (2.5.0)
# Requirement already satisfied: certifi in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mediapipe) (2026.7.22)
# Requirement already satisfied: numpy in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mediapipe) (2.5.1)
# Requirement already satisfied: sounddevice~=0.5 in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mediapipe) (0.5.6)
# Requirement already satisfied: flatbuffers~=25.9 in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mediapipe) (25.12.19)
# Requirement already satisfied: opencv-contrib-python in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mediapipe) (5.0.0.93)
# Requirement already satisfied: matplotlib in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mediapipe) (3.11.2)
# Requirement already satisfied: cffi in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sounddevice~=0.5->mediapipe) (2.1.1)
# Requirement already satisfied: pycparser in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from cffi->sounddevice~=0.5->mediapipe) (3.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib->mediapipe) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib->mediapipe) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib->mediapipe) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib->mediapipe) (26.3)
# Requirement already satisfied: pillow>=9 in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib->mediapipe) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib->mediapipe) (3.3.3)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Shashwat Bhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import mediapipe as mp

# Load OpenCV's built-in face detector
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)

cap = cv2.VideoCapture(0)

while cap.isOpened():
  success, frame = cap.read()
  if not success:
    break

  # Convert frame to grayscale for detection
  gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

  # Detect faces
  faces = face_cascade.detectMultiScale(
      gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30)
  )

  # Draw rectangle around detected faces
  for x, y, w, h in faces:
    cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

  cv2.imshow('BCA AI Demo - Face Detection', frame)

  if cv2.waitKey(1) & 0xFF == ord('q'):
    break

cap.release()
cv2.destroyAllWindows()import cv2
import mediapipe as mp

# Load OpenCV's built-in face detector
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)

cap = cv2.VideoCapture(0)

while cap.isOpened():
  success, frame = cap.read()
  if not success:
    break

  # Convert frame to grayscale for detection
  gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

  # Detect faces
  faces = face_cascade.detectMultiScale(
      gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30)
  )

  # Draw rectangle around detected faces
  for x, y, w, h in faces:
    cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

  cv2.imshow('BCA AI Demo - Face Detection', frame)

  if cv2.waitKey(1) & 0xFF == ord('q'):
    break

cap.release()
cv2.destroyAllWindows()
# Out:
#   Cell In[4], line 34
#     cv2.destroyAllWindows()import cv2
#                            ^
# SyntaxError: invalid syntax
