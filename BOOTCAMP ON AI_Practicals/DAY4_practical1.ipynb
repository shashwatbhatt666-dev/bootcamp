# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r'C:\Users\Shashwat Bhatt\Downloads/3.jpg')
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
cv2.imshow('image', img)
cv2.waitKey(0)
# Out:
# -1

# %%
img_resize=cv2.resize(img, (400,256))
cv2.imshow('image', img_resize)
cv2.waitKey(0)
# Out:
# -1

# %%
img_crop=img[100:400, 200:500]
cv2.imshow('image', img_crop)
cv2.waitKey(0)  
cv2.destroyAllWindows()
